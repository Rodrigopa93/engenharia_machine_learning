# %%
# Carregando o dataset
data = catalog.load('data_raw')
# Out:
# [04/17/23 19:03:28] INFO     Loading data from 'data_raw' (CSVDataSet)...                       ]8;id=107293;file://C:\Users\rodri\Projetos\engenharia_machine_learning\env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=726113;file://C:\Users\rodri\Projetos\engenharia_machine_learning\env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\

# %%
# Filtrando os dados
data_3pt_field_goal = data[data['shot_type'] == '3PT Field Goal']

# Removendo linhas faltantes
data_3pt = data_3pt_field_goal.dropna()
data_3pt
# Out:
#            lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 10     33.8063 -118.3638                  1       3         0             25
# 17     33.8183 -118.3868                  8       2         0             25
# 27     33.8583 -118.4528                  0       3         0             26
# 39     33.7723 -118.2968                  0       2         0             27
# 55     33.8503 -118.4248                  2       1         0             24
# ...        ...       ...                ...     ...       ...            ...
# 30675  33.8283 -118.4038                  2       1         1             25
# 30681  33.7833 -118.2878                  0       2         1             26
# 30685  33.7943 -118.1888                  7       3         1             26
# 30689  33.3653 -118.2818                  0       3         1             67
# 30695  33.7773 -118.2388                  2       4         1             26
#
#        shot_made_flag       shot_type
# ...

# %%
X = data_3pt[["lat", "lon", "minutes_remaining", "period", "playoffs", "shot_distance"]]
y_true = data_3pt["shot_made_flag"]

# %%
import json
import requests

url = 'http://localhost:5001/invocations'

# Define o formato dos dados de entrada
headers = {"Content-Type": "application/json"}

# Cria um dicionário com os dados de entrada
data_dict = X.to_dict(orient="records")

# Converte o dicionário em uma string JSON
json_data = json.dumps(data_dict)

# Faz uma solicitação POST para a URL de implantação do modelo
response = requests.post(url, headers=headers, data=json_data)

# Extrai as previsões do objeto de resposta
y_pred = json.loads(response.text)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\rodri\Projetos\engenharia_machine_learning\env\lib\site-packages\urllib3\connection.py: │
# │ 174 in _new_conn                                                                                 │
# │                                                                                                  │
# │   171 │   │   │   extra_kw["socket_options"] = self.socket_options                               │
# │   172 │   │                                                                                      │
# │   173 │   │   try:                                                                               │
# │ ❱ 174 │   │   │   conn = connection.create_connection(                                           │
# │   175 │   │   │   │   (self._dns_host, self.port), self.timeout, **extra_kw                      │
# ...

# %%
response_json = json.loads(response.text)
log_loss = response_json['log_loss']
f1_score = response_json['f1_score']
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 response_json = json.loads(response.text)                                                    │
# │   2 log_loss = response_json['log_loss']                                                         │
# │   3 f1_score = response_json['f1_score']                                                         │
# │   4                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'response' is not defined
